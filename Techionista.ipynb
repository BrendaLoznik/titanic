# %% [markdown]
# <a href="https://colab.research.google.com/github/BrendaLoznik/titanic/blob/main/Techionista.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**The titanic!**

# %% [markdown]
# ![titanic.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **1 Housekeeping**

# %%
#import basic libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# #### **1.2 Load data**

# %%
#connect google colab with Google Drive
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
#load the data from Google Drive
path = '/content/gdrive/MyDrive/Kaggle/techionista/data/train.csv'
df = pd.read_csv(path)

# %%
#display the first 5 rows
df.head()

# %% [markdown]
# # **2 Explore the data**

# %% [markdown]
# ### **2.1 Did women have a greater chance of survival?**

# %%
#create a count plot
ax = sns.countplot(data = df, x = 'Survived', hue = 'Sex', palette = 'Set1')  
ax.set(title = 'Survival by gender', ylabel = 'Number of passengers')
plt.show()
